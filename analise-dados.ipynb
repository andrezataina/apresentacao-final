# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
import csv

# %%
import sqlite3
import csv

# %%
df = pd.read_csv(r'C:\Users\andre\OneDrive\Área de Trabalho\REPROGRAMA\APRESENTACAO FINAL\TDI_2023_BRASIL_REGIOES_UFS\pdde_campo_escolas_2009a2024.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#   NO_REGIAO;CO_REGIAO;NO_UF;SG_UF;CO_UF;CO_MUNICIPIO;NO_MUNICIPIO;CO_ENTIDADE;NO_ENTIDADE;TP_SITUACAO_FUNCIONAMENTO;CO_MUNICIPIO;TP_DEPENDENCIA;Modalidade SECADI;TP_LOCALIZACAO_DIFERENCIADA;QT_MAT_BAS_2023;com_UEX_até_01_07_2024;Empenhadas_CAMPO_2009a2024;PAGAS_CAMPO_ATÉ_01_07_2024;valor_empenhado_campo_2009a2024;valor_pago_campo_2009_até_01_07_2024;Campo_Ano_2009;Alunos_Campo_2009;Valor_Campo_2009;Pagas_Campo_2009;Campo_Ano_2010;Alunos_Campo_2010;Valor_Campo_2010;Pagas_Campo_2010;Campo_Ano_2011;Alunos_Campo_2011;Valor_Campo_2011;Pagas_Campo_2011;Campo_Ano_2012;Alunos_Campo_2012;Valor_Campo_2012;Pagas_Campo_2012;Campo_Ano_2013;Alunos_Campo_2013;Valor_Campo_2013;Pagas_Campo_2013;Campo1_Ano_2014;Alunos_Campo1_2014;Valor_Campo1_2014;Pagas_Campo1_2014;Campo2_Ano_2014;Alunos_Campo2_2014;Valor_Campo2_2014;Pagas_Campo2_2014;Campo_Ano_2015;Alunos_Campo_2015;Valor_Campo_2015;Pagas_Campo_2015;Campo2_Ano_2015;Alunos_Campo2_2015;Valor_Campo2_2015;Pagas_Campo2_2015;Campo_Ano_2017;Alunos_Campo_201
# ...

# %%
info_df = df.info()

print(info_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38282 entries, 0 to 38281
# Data columns (total 1 columns):
# ...
